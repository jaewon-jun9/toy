# %%
#crop ocr
from PIL import Image
from pytesseract import *
import cv2
pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

filename = "f:\\20201012095655865_page01.png"
img = cv2.imread(filename)

blk_size = 9        # 블럭 사이즈
C = 5               # 차감 상수 
win_name = 'scan'
# 이미지 읽기
#img = cv2.imread(img)
# cv2.imshow('original', img)
# cv2.waitKey(0)
draw = img.copy()

# 그레이스 스케일 변환 및 케니 엣지
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, blk_size, C)
#gray = cv2.GaussianBlur(gray, (3, 3), 0) # 가우시안 블러로 노이즈 제거
#edged = cv2.Canny(gray, 75, 200)    # 케니 엣지로 경계 검출
cv2.imshow(win_name, gray)
cv2.waitKey(0)


#이미지를 50줄 씩만 읽기
lineLenth=47
readLines=0
count=1
while len(gray)>readLines:
    cropped = gray[readLines:lineLenth*count,0:1110]
    text = image_to_string(cropped,lang="eng")
    print(text)
    cv2.imshow("cropped line", cropped)
    readLines=readLines+lineLenth
    count=count+1
    #cv2.imshow("Original", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
#
#
#
#
#
#
#
#
#
#
# | Adas | us | ARease i BEEF] U |7IET 1 | 4% |
#
# [
# l
# a
#
#
#
#
#
#
# : 1 I I I 1 I
# | 2010-05-01 |CDOiiﬂ I #3,000,000 “42,150,134 | 1 | 5007 | 1195|Ell73|9~1
#
# A
#
#
#
#
# : T I 1 1 h 7 I ! ' !
# | 2010-06-12 lCDOIiﬂ I #3,000,000 E “39,160,134 I 5118 l 1195 | Elli|§|
#
# a
# F4
#
#
# | 2010-06-14 lCD§§| w700,000 | ”118.450.1154 | | | 5008 |1363 |€Ulo|
#
#
#
#
# | 2010-05-14 [CDEEIT #700, 000 W37.760,131[ | I | 5008 | 1983 |~ED}O}|
#
#
#
#
# | 2010-05-14 lw’éi‘ #200,000 W37.060.131l | | 5003 11363 Eolof
#
#
# wes
#
# i2010-05-2417IEE—l “1,251,494 Fjﬂ'5}5 r— W35,808,632| i | - i 0 i 5 |
#
#
#
#
#
#
# |zo1o-05-25lerglpcl i7 165,000 8341501 “12,974,634 | I | 0 | 7 |(%ﬂ)|
#
#
#
#
# | 2010-05-25 [FBX|%[_ 250,000 [mkt oos-0ss l‘x’42.724.63_2-l | 1 I 0 | 521Sl73§lMCI
#
#
#
#
#
#
# | 2010-05-28 ‘FBSL’ #30, 070 W42,635.56;I— I 1 I 0 |6003 | Barn
#
#
#
#
# #so,000) [stl s i= ao! w42.535,552| i | | 5003 | 1195 | clalet I
#
#
#
# | 2010-06-25 ‘CDOIiU
#
#
#
#
#
#
# I 2010-05-19 I olxt #8,494003,20-08. 18 W42.594.058I I I I 0 I 1195 Icﬂﬂlq I
#
#
#
#
#
#
# I 2010-08-21 ‘ Ue 1
#
# attiats W42.020.517[ | ‘ 0 5 l'ﬂ’dﬂ‘
#
# NSr3, 599
#
#
#
#
#
#
#
#
#
#
#
#
# 2010-06-25
#
#
#
# shire
#
#
#
#
#
# wr, 165,000
#
#
#
# dB g
#
# #49, 185, 517)
#
#
#
#
#
#
#
#
#
#
#
#
#
# #1
#
#
#
#
#
#
#
#
#
#
# 2010-06-25
#
#
#
# RAE
#
#
#
# #aso, 000!
#
#
#
#
#
# 1.11111 006-054
#
#
#
# we,005, 517)
#
#
#
#
#
#
#
#
#
# seis |
#
#
#
#
#
#
#
#
# | 2010-06-28 ‘ FSA
#
#
#
# hod, 770 ‘010378972265KT t#8,831 .747‘ I I 0 | ots
#
#
#
#
#
# Ban i
#
#
# | 2010-07-21 ' fea |
#
# 130,000
#
# 3
#
# tie
#
# W48,692,747| ‘
#
#
#
#
# | 2010-07-22 I cool | W3.UUO,DOU| A84 W45‘692,747‘ ; | | $009 | nos |olajel
#
#
#
#
#
#
#
#
# | 2010-07-28
#
#
#
# E}‘?=“PC| | w7 165, 000(0t 3 es a) wsz,sse.747} I | | o ‘ 7 |(=g§)|
#
#
#
#
#
#
# | 2010-07-25 I FBEA!
#
#
#
# w70,770 otosresrzzeskT | W52.7B7.977| l | | 0 |6003| an I
#
#
#
#
# | 2010-07-26 xFBKI—E— | #250,000 |.TL‘5’.1007-055 | W52,537.977| I | | 0 | 5216 I3im€|
#
#
#
#
# |zo1o-os—1o|cpa|x||| #2,000,000 a=« wso.537,977l | | I5001l1195|£ui|21|
#
#
#
#
# |201o-oe~1s[ ES #s, 000,000 W45,537,977| 1 |oaa| a [neslcllxlﬁit
